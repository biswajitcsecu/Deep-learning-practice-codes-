# %%
import glob
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
import random
from random import randint
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import keras
from keras.models import load_model
from keras.layers import Dense
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Flatten
import tensorflow as tf
plt.style.use('ggplot')
# Out:
# Using TensorFlow backend.

# %%
targets = []
features = []
print('start parsing ...')
files = glob.glob('hymenoptera/train/ants/*.jpg')
random.shuffle(files)
print('parsing ok.')

for file in files:
    features.append(np.array(Image.open(file).resize((100, 100))))
    target = [1, 0] if "amd" in file else [0, 1]
    targets.append(target)

features = np.array(features)
targets = np.array(targets)

print (features.shape)
print (targets.shape)
# Out:
# start parsing ...
# parsing ok.
# (122, 100, 100, 3)
# (122, 2)

# %%
for idx in [randint(0, len(features)) for _ in range(5)]:
    plt.imshow(features[idx])
    plt.grid(False)
    plt.show()

# %%
X_train, X_valid, y_train, y_valid = train_test_split(features,
                        targets, test_size=0.3, random_state=42)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(8, 8), strides=(1, 1),
                 activation='relu', input_shape=(100, 100, 3), padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Conv2D(64, (5, 5), strides=(1, 1), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Conv2D(128, (5, 5), strides=(1, 1), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Conv2D(256, (5, 5), strides=(1, 1), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Conv2D(215, (5, 5), strides=(1, 1), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 100, 100, 32)      6176
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 128)       204928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 256)       819456
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 215)         1376215
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 215)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3440)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                220224
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 2,678,393
# Trainable params: 2,678,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.SGD(lr=0.0001, momentum=0.9),
              loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train,
          batch_size=100,
          epochs=50,
          verbose=1,
          validation_data=(X_valid, y_valid))
# Out:
# Train on 85 samples, validate on 37 samples
# Epoch 1/50
# 85/85 [==============================] - 16s 189ms/step - loss: 4.5359 - acc: 0.4706 - val_loss: 7.8296e-05 - val_acc: 1.0000
# Epoch 2/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2534 - acc: 0.9412 - val_loss: 1.2249e-07 - val_acc: 1.0000
# Epoch 3/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0499 - acc: 0.9882 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 4/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 5/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0390 - acc: 0.9882 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 6/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0046 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 7/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0076 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 8/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0042 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 9/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 10/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 11/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0090 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 12/50
# 85/85 [==============================] - 1s 10ms/step - loss: 3.2239e-05 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 13/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0242 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 14/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.5094e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 15/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.1243e-06 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 16/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0383 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 17/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0152 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 18/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0966e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 19/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.1521e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 20/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 21/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.1170e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 22/50
# 85/85 [==============================] - 1s 10ms/step - loss: 2.3503e-06 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 23/50
# 85/85 [==============================] - 1s 10ms/step - loss: 4.0060e-04 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 24/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0980e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 25/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 26/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 27/50
# 85/85 [==============================] - 1s 10ms/step - loss: 8.1924e-06 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 28/50
# 85/85 [==============================] - 1s 10ms/step - loss: 2.9514e-05 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 29/50
# 85/85 [==============================] - 1s 10ms/step - loss: 9.4826e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 30/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 31/50
# 85/85 [==============================] - 1s 10ms/step - loss: 9.7760e-04 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 32/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 33/50
# 85/85 [==============================] - 1s 10ms/step - loss: 9.5571e-04 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 34/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0221 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 35/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.3164e-05 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 36/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 37/50
# 85/85 [==============================] - 1s 10ms/step - loss: 5.8954e-06 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 38/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 39/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 40/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.1171e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 41/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0515e-04 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 42/50
# 85/85 [==============================] - 1s 10ms/step - loss: 5.7946e-05 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 43/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.8389e-04 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 44/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 45/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.1241e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 46/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 47/50
# 85/85 [==============================] - 1s 10ms/step - loss: 8.7258e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 48/50
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0505 - acc: 0.9941 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 49/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.0960e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 50/50
# 85/85 [==============================] - 1s 10ms/step - loss: 1.2971e-07 - acc: 1.0000 - val_loss: 1.0960e-07 - val_acc: 1.0000

# %%
model.save('model.h5')
model.save_weights('model_w.h5')

# %%
plt.figure(figsize=(20,10)) 
plt.style.use('ggplot')
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20,10)) 
plt.style.use('ggplot')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
img_width, img_height = 100, 100
input_shape = (img_width, img_height, 3)

# %%
test_model = load_model('model.h5')

# %%
path = 'hymenoptera/train/ants/560966032_988f4d7bc4.jpg'
img = load_img(path, False, target_size = (img_width, img_height))
plt.imshow(img)
plt.grid(False)
x = img_to_array(img)
x = np.expand_dims(x, axis=0)
pred = test_model.predict_classes(x)
prob = test_model.predict_proba(x)
print(pred)
print(prob)
if pred == [[0]]:
    print('BEE :/')
else:
    print('ANT')
# Out:
# [1]
# [[0. 1.]]
# ANT
